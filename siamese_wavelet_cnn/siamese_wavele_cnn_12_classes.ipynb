# %%
import numpy as np
from matplotlib import pyplot as plt
import re
import os
import random
import pandas as pd
import tensorflow as tf
import keras
import glob
import cv2
import numpy as np
from random import shuffle
from tqdm import tqdm
from tensorflow.python.framework import graph_util
from keras.layers import *
from keras.optimizers import *
import sys
import pandas as pd
import pickle
import time
from keras.models import Model, Sequential
from keras.regularizers import l2
from keras import backend as K
from keras.optimizers import Adam
from skimage.io import imshow
from keras.layers.normalization import BatchNormalization
from keras.initializers import glorot_uniform
from keras.engine.topology import Layer
from sklearn.utils import shuffle
import numpy.random as rng
from keras.utils import to_categorical
from keras.utils import np_utils
from keras.utils import to_categorical
from keras.models import Model, load_model
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img
from sklearn.model_selection import train_test_split
from functools import partial, update_wrapper
import pydot
#install pip pydot_ng
from keras import backend as K
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Conv2D
from keras.layers import Lambda
from keras.layers import Flatten
from keras.layers import Reshape
from keras.layers import Dropout
from keras.layers import Activation
from keras.layers import AveragePooling2D
from keras.layers import BatchNormalization
from keras.layers.merge import add, concatenate
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import plot_model
import pydot
#install pip pydot_ng
import pydot_ng as pydot
print (pydot.find_graphviz())
np.random.seed(42)
# %matplotlib inline
plt.rcParams['image.cmap'] = 'gray'
# Out:
# Using TensorFlow backend.
# {'dot': 'C:\\Program Files\\Graphviz 2.44.1\\bin\\dot.exe', 'twopi': '', 'neato': '', 'circo': '', 'fdp': '', 'sfdp': ''}

# %%
#print("tf.version is", tf.version)
#print("tf.keras.version is:", tf.keras.version)

def _get_available_gpus():
    """Get a list of available gpu devices (formatted as strings).

    # Returns
        A list of available GPU devices.
    """
    #global _LOCAL_DEVICES
    if tfback._LOCAL_DEVICES is None:
        devices = tf.config.list_logical_devices()
        tfback._LOCAL_DEVICES = [x.name for x in devices]
    return [x for x in tfback._LOCAL_DEVICES if 'device:gpu' in x.lower()]

#tfback._get_available_gpus = _get_available_gpus
#tfback._get_available_gpus()
#tf.config.list_logical_devices()

# %%
DIMEN = 224

X1 = np.load( 'processed_data/x1.npy')
X2 = np.load( 'processed_data/x2.npy')
Y = np.load( 'processed_data/y.npy')

X1 = X1.reshape( ( X1.shape[0]  , DIMEN**2 * 3  ) ).astype( np.float32 )
X2 = X2.reshape( ( X2.shape[0]  , DIMEN**2 * 3  ) ).astype( np.float32 )

train_X1 = X1[ : 4500 ] 
train_X2 = X2[ : 4500 ] 
train_Y = Y[ : 4500 ] 

test_X1 = X1[ 4500 : ]
test_X2 = X2[ 4500 : ] 
test_Y = Y[ 4500 : ]
 
print(  train_X1.shape )
print(  train_X2.shape )
print(  train_Y.shape )

print(test_X1.shape )
print(test_X2.shape )
print(test_Y.shape)
# Out:
# (4500, 150528)
# (4500, 150528)
# (4500, 1)
# (5701, 150528)
# (5701, 150528)
# (5701, 1)

# %% [markdown]
# # ValueError: Error when checking input: expected input_3 to have 4 dimensions, but got array with shape (4500, 150528)
# 1. in order to avoid running into the above error, kindly reshape the inputs data into 4 dimensions i.e (4500, 224, 224, 3)

# %%
train_X1 = train_X1.reshape(-1,224, 224, 3)   #Reshape for CNN -  should work!!
train_X2 = train_X2.reshape(-1,224, 224, 3)

test_X1 = test_X1.reshape(-1,224, 224, 3)
test_X2 = test_X2.reshape(-1,224, 224, 3)

# %%
print(  train_X1.shape )
print(  train_X2.shape )
print(  train_Y.shape )

print(test_X1.shape )
print(test_X2.shape )
print(test_Y.shape)
# Out:
# (4500, 224, 224, 3)
# (4500, 224, 224, 3)
# (4500, 1)
# (5701, 224, 224, 3)
# (5701, 224, 224, 3)
# (5701, 1)

# %%
input_shape = (224, 224, 3)

# %%
# batch operation usng tensor slice
def WaveletTransformAxisY(batch_img):
    odd_img  = batch_img[:,0::2]
    even_img = batch_img[:,1::2]
    L = (odd_img + even_img) / 2.0
    H = K.abs(odd_img - even_img)
    return L, H

def WaveletTransformAxisX(batch_img):
    # transpose + fliplr
    tmp_batch = K.permute_dimensions(batch_img, [0, 2, 1])[:,:,::-1]
    _dst_L, _dst_H = WaveletTransformAxisY(tmp_batch)
    # transpose + flipud
    dst_L = K.permute_dimensions(_dst_L, [0, 2, 1])[:,::-1,...]
    dst_H = K.permute_dimensions(_dst_H, [0, 2, 1])[:,::-1,...]
    return dst_L, dst_H

# %%
def Wavelet(batch_image):
    # make channel first image
    batch_image = K.permute_dimensions(batch_image, [0, 3, 1, 2])
    r = batch_image[:,0]
    g = batch_image[:,1]
    b = batch_image[:,2]

    # level 1 decomposition
    wavelet_L, wavelet_H = WaveletTransformAxisY(r)
    r_wavelet_LL, r_wavelet_LH = WaveletTransformAxisX(wavelet_L)
    r_wavelet_HL, r_wavelet_HH = WaveletTransformAxisX(wavelet_H)

    wavelet_L, wavelet_H = WaveletTransformAxisY(g)
    g_wavelet_LL, g_wavelet_LH = WaveletTransformAxisX(wavelet_L)
    g_wavelet_HL, g_wavelet_HH = WaveletTransformAxisX(wavelet_H)

    wavelet_L, wavelet_H = WaveletTransformAxisY(b)
    b_wavelet_LL, b_wavelet_LH = WaveletTransformAxisX(wavelet_L)
    b_wavelet_HL, b_wavelet_HH = WaveletTransformAxisX(wavelet_H)

    wavelet_data = [r_wavelet_LL, r_wavelet_LH, r_wavelet_HL, r_wavelet_HH, 
                    g_wavelet_LL, g_wavelet_LH, g_wavelet_HL, g_wavelet_HH,
                    b_wavelet_LL, b_wavelet_LH, b_wavelet_HL, b_wavelet_HH]
    transform_batch = K.stack(wavelet_data, axis=1)

    # level 2 decomposition
    wavelet_L2, wavelet_H2 = WaveletTransformAxisY(r_wavelet_LL)
    r_wavelet_LL2, r_wavelet_LH2 = WaveletTransformAxisX(wavelet_L2)
    r_wavelet_HL2, r_wavelet_HH2 = WaveletTransformAxisX(wavelet_H2)

    wavelet_L2, wavelet_H2 = WaveletTransformAxisY(g_wavelet_LL)
    g_wavelet_LL2, g_wavelet_LH2 = WaveletTransformAxisX(wavelet_L2)
    g_wavelet_HL2, g_wavelet_HH2 = WaveletTransformAxisX(wavelet_H2)

    wavelet_L2, wavelet_H2 = WaveletTransformAxisY(b_wavelet_LL)
    b_wavelet_LL2, b_wavelet_LH2 = WaveletTransformAxisX(wavelet_L2)
    b_wavelet_HL2, b_wavelet_HH2 = WaveletTransformAxisX(wavelet_H2)


    wavelet_data_l2 = [r_wavelet_LL2, r_wavelet_LH2, r_wavelet_HL2, r_wavelet_HH2, 
                    g_wavelet_LL2, g_wavelet_LH2, g_wavelet_HL2, g_wavelet_HH2,
                    b_wavelet_LL2, b_wavelet_LH2, b_wavelet_HL2, b_wavelet_HH2]
    transform_batch_l2 = K.stack(wavelet_data_l2, axis=1)

    # level 3 decomposition
    wavelet_L3, wavelet_H3 = WaveletTransformAxisY(r_wavelet_LL2)
    r_wavelet_LL3, r_wavelet_LH3 = WaveletTransformAxisX(wavelet_L3)
    r_wavelet_HL3, r_wavelet_HH3 = WaveletTransformAxisX(wavelet_H3)

    wavelet_L3, wavelet_H3 = WaveletTransformAxisY(g_wavelet_LL2)
    g_wavelet_LL3, g_wavelet_LH3 = WaveletTransformAxisX(wavelet_L3)
    g_wavelet_HL3, g_wavelet_HH3 = WaveletTransformAxisX(wavelet_H3)

    wavelet_L3, wavelet_H3 = WaveletTransformAxisY(b_wavelet_LL2)
    b_wavelet_LL3, b_wavelet_LH3 = WaveletTransformAxisX(wavelet_L3)
    b_wavelet_HL3, b_wavelet_HH3 = WaveletTransformAxisX(wavelet_H3)

    wavelet_data_l3 = [r_wavelet_LL3, r_wavelet_LH3, r_wavelet_HL3, r_wavelet_HH3, 
                    g_wavelet_LL3, g_wavelet_LH3, g_wavelet_HL3, g_wavelet_HH3,
                    b_wavelet_LL3, b_wavelet_LH3, b_wavelet_HL3, b_wavelet_HH3]
    transform_batch_l3 = K.stack(wavelet_data_l3, axis=1)

    # level 4 decomposition
    wavelet_L4, wavelet_H4 = WaveletTransformAxisY(r_wavelet_LL3)
    r_wavelet_LL4, r_wavelet_LH4 = WaveletTransformAxisX(wavelet_L4)
    r_wavelet_HL4, r_wavelet_HH4 = WaveletTransformAxisX(wavelet_H4)

    wavelet_L4, wavelet_H4 = WaveletTransformAxisY(g_wavelet_LL3)
    g_wavelet_LL4, g_wavelet_LH4 = WaveletTransformAxisX(wavelet_L4)
    g_wavelet_HL4, g_wavelet_HH4 = WaveletTransformAxisX(wavelet_H4)

    wavelet_L3, wavelet_H3 = WaveletTransformAxisY(b_wavelet_LL3)
    b_wavelet_LL4, b_wavelet_LH4 = WaveletTransformAxisX(wavelet_L4)
    b_wavelet_HL4, b_wavelet_HH4 = WaveletTransformAxisX(wavelet_H4)


    wavelet_data_l4 = [r_wavelet_LL4, r_wavelet_LH4, r_wavelet_HL4, r_wavelet_HH4, 
                    g_wavelet_LL4, g_wavelet_LH4, g_wavelet_HL4, g_wavelet_HH4,
                    b_wavelet_LL4, b_wavelet_LH4, b_wavelet_HL4, b_wavelet_HH4]
    transform_batch_l4 = K.stack(wavelet_data_l4, axis=1)

    # print('shape before')
    # print(transform_batch.shape)
    # print(transform_batch_l2.shape)
    # print(transform_batch_l3.shape)
    # print(transform_batch_l4.shape)

    decom_level_1 = K.permute_dimensions(transform_batch, [0, 2, 3, 1])
    decom_level_2 = K.permute_dimensions(transform_batch_l2, [0, 2, 3, 1])
    decom_level_3 = K.permute_dimensions(transform_batch_l3, [0, 2, 3, 1])
    decom_level_4 = K.permute_dimensions(transform_batch_l4, [0, 2, 3, 1])
    
    # print('shape after')
    # print(decom_level_1.shape)
    # print(decom_level_2.shape)
    # print(decom_level_3.shape)
    # print(decom_level_4.shape)
    return [decom_level_1, decom_level_2, decom_level_3, decom_level_4]


def Wavelet_out_shape(input_shapes):
    # print('in to shape')
    return [tuple([None, 112, 112, 12]), tuple([None, 56, 56, 12]), 
            tuple([None, 28, 28, 12]), tuple([None, 14, 14, 12])]

# %%
img_batch = K.zeros(shape=(8, 224, 224, 3), dtype='float32')
Wavelet(img_batch)
# Out:
# [<tf.Tensor 'transpose_73:0' shape=(8, 112, 112, 12) dtype=float32>,
#  <tf.Tensor 'transpose_74:0' shape=(8, 56, 56, 12) dtype=float32>,
#  <tf.Tensor 'transpose_75:0' shape=(8, 28, 28, 12) dtype=float32>,
#  <tf.Tensor 'transpose_76:0' shape=(8, 14, 14, 12) dtype=float32>]

# %%
def get_wavelet_cnn_model():

    input_shape = 224, 224, 3

    input_ = Input(input_shape, name='the_input')
    # wavelet = Lambda(Wavelet, name='wavelet')
    wavelet = Lambda(Wavelet, Wavelet_out_shape, name='wavelet')
    input_l1, input_l2, input_l3, input_l4 = wavelet(input_)
    # print(input_l1)
    # print(input_l2)
    # print(input_l3)
    # print(input_l4)
    # level one decomposition starts
    conv_1 = Conv2D(64, kernel_size=(3, 3), padding='same', name='conv_1')(input_l1)
    norm_1 = BatchNormalization(name='norm_1')(conv_1)
    relu_1 = Activation('relu', name='relu_1')(norm_1)

    conv_1_2 = Conv2D(64, kernel_size=(3, 3), strides=(2, 2), padding='same', name='conv_1_2')(relu_1)
    norm_1_2 = BatchNormalization(name='norm_1_2')(conv_1_2)
    relu_1_2 = Activation('relu', name='relu_1_2')(norm_1_2)

    # level two decomposition starts
    conv_a = Conv2D(filters=64, kernel_size=(3, 3), padding='same', name='conv_a')(input_l2)
    norm_a = BatchNormalization(name='norm_a')(conv_a)
    relu_a = Activation('relu', name='relu_a')(norm_a)

    # concate level one and level two decomposition
    concate_level_2 = concatenate([relu_1_2, relu_a])
    conv_2 = Conv2D(128, kernel_size=(3, 3), padding='same', name='conv_2')(concate_level_2)
    norm_2 = BatchNormalization(name='norm_2')(conv_2)
    relu_2 = Activation('relu', name='relu_2')(norm_2)

    conv_2_2 = Conv2D(128, kernel_size=(3, 3), strides=(2, 2), padding='same', name='conv_2_2')(relu_2)
    norm_2_2 = BatchNormalization(name='norm_2_2')(conv_2_2)
    relu_2_2 = Activation('relu', name='relu_2_2')(norm_2_2)

    # level three decomposition starts 
    conv_b = Conv2D(filters=64, kernel_size=(3, 3), padding='same', name='conv_b')(input_l3)
    norm_b = BatchNormalization(name='norm_b')(conv_b)
    relu_b = Activation('relu', name='relu_b')(norm_b)

    conv_b_2 = Conv2D(128, kernel_size=(3, 3), padding='same', name='conv_b_2')(relu_b)
    norm_b_2 = BatchNormalization(name='norm_b_2')(conv_b_2)
    relu_b_2 = Activation('relu', name='relu_b_2')(norm_b_2)

    # concate level two and level three decomposition 
    concate_level_3 = concatenate([relu_2_2, relu_b_2])
    conv_3 = Conv2D(256, kernel_size=(3, 3), padding='same', name='conv_3')(concate_level_3)
    norm_3 = BatchNormalization(name='nomr_3')(conv_3)
    relu_3 = Activation('relu', name='relu_3')(norm_3)

    conv_3_2 = Conv2D(256, kernel_size=(3, 3), strides=(2, 2), padding='same', name='conv_3_2')(relu_3)
    norm_3_2 = BatchNormalization(name='norm_3_2')(conv_3_2)
    relu_3_2 = Activation('relu', name='relu_3_2')(norm_3_2)

    # level four decomposition start
    conv_c = Conv2D(64, kernel_size=(3, 3), padding='same', name='conv_c')(input_l4)
    norm_c = BatchNormalization(name='norm_c')(conv_c)
    relu_c = Activation('relu', name='relu_c')(norm_c)

    conv_c_2 = Conv2D(256, kernel_size=(3, 3), padding='same', name='conv_c_2')(relu_c)
    norm_c_2 = BatchNormalization(name='norm_c_2')(conv_c_2)
    relu_c_2 = Activation('relu', name='relu_c_2')(norm_c_2)

    conv_c_3 = Conv2D(256, kernel_size=(3, 3), padding='same', name='conv_c_3')(relu_c_2)
    norm_c_3 = BatchNormalization(name='norm_c_3')(conv_c_3)
    relu_c_3 = Activation('relu', name='relu_c_3')(norm_c_3)

    # concate level level three and level four decomposition
    concate_level_4 = concatenate([relu_3_2, relu_c_3])
    conv_4 = Conv2D(256, kernel_size=(3, 3), padding='same', name='conv_4')(concate_level_4)
    norm_4 = BatchNormalization(name='norm_4')(conv_4)
    relu_4 = Activation('relu', name='relu_4')(norm_4)

    conv_4_2 = Conv2D(256, kernel_size=(3, 3), strides=(2, 2), padding='same', name='conv_4_2')(relu_4)
    norm_4_2 = BatchNormalization(name='norm_4_2')(conv_4_2)
    relu_4_2 = Activation('relu', name='relu_4_2')(norm_4_2)

    conv_5_1 = Conv2D(128, kernel_size=(3, 3), padding='same', name='conv_5_1')(relu_4_2)
    norm_5_1 = BatchNormalization(name='norm_5_1')(conv_5_1)
    relu_5_1 = Activation('relu', name='relu_5_1')(norm_5_1)

    pool_5_1 = AveragePooling2D(pool_size=(7, 7), strides=1, padding='same', name='avg_pool_5_1')(relu_5_1)
    flat_5_1 = Flatten(name='flat_5_1')(pool_5_1) 

    fc_5 = Dense(2048, name='fc_5')(flat_5_1)
    norm_5 = BatchNormalization(name='norm_5')(fc_5)
    relu_5 = Activation('relu', name='relu_5')(norm_5)
    drop_5 = Dropout(0.5, name='drop_5')(relu_5)

    fc_6 = Dense(2048, name='fc_6')(drop_5)
    norm_6 = BatchNormalization(name='norm_6')(fc_6)
    relu_6 = Activation('relu', name='relu_6')(norm_6)
    drop_6 = Dropout(0.5, name='drop_6')(relu_6)

    output = Dense(1024, activation='sigmoid', name='fc_7')(drop_6)
    #output = Dense(1, activation='sigmoid', name='fc_7')(drop_6)

    model = Model(inputs=input_, outputs=output)
    model.summary()
    plot_model(model, to_file='Neurowavelet_Siamese_Classification_2classes.png')
    #plot_model(model, show_shapes=True, show_layer_names=True)

    return model

# %%
img1 = Input(shape=(224, 224, 3))
img2 = Input(shape=(224, 224, 3))

# %%
siamese_model = get_wavelet_cnn_model()
siamese_model.summary()
#plot_model(siamese_model, show_shapes=True, show_layer_names=True)
# Out:
# WARNING:tensorflow:From C:\Users\PC\Anaconda3\envs\grace\lib\site-packages\keras\backend\tensorflow_backend.py:4074: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# the_input (InputLayer)          (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# wavelet (Lambda)                [(None, 112, 112, 12 0           the_input[0][0]
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 112, 112, 64) 6976        wavelet[0][0]
# __________________________________________________________________________________________________
# norm_1 (BatchNormalization)     (None, 112, 112, 64) 256         conv_1[0][0]
# __________________________________________________________________________________________________
# relu_1 (Activation)             (None, 112, 112, 64) 0           norm_1[0][0]
# __________________________________________________________________________________________________
# conv_1_2 (Conv2D)               (None, 56, 56, 64)   36928       relu_1[0][0]
# __________________________________________________________________________________________________
# conv_a (Conv2D)                 (None, 56, 56, 64)   6976        wavelet[0][1]
# __________________________________________________________________________________________________
# norm_1_2 (BatchNormalization)   (None, 56, 56, 64)   256         conv_1_2[0][0]
# __________________________________________________________________________________________________
# norm_a (BatchNormalization)     (None, 56, 56, 64)   256         conv_a[0][0]
# __________________________________________________________________________________________________
# relu_1_2 (Activation)           (None, 56, 56, 64)   0           norm_1_2[0][0]
# __________________________________________________________________________________________________
# relu_a (Activation)             (None, 56, 56, 64)   0           norm_a[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 56, 56, 128)  0           relu_1_2[0][0]
#                                                                  relu_a[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 56, 56, 128)  147584      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv_b (Conv2D)                 (None, 28, 28, 64)   6976        wavelet[0][2]
# __________________________________________________________________________________________________
# norm_2 (BatchNormalization)     (None, 56, 56, 128)  512         conv_2[0][0]
# __________________________________________________________________________________________________
# norm_b (BatchNormalization)     (None, 28, 28, 64)   256         conv_b[0][0]
# __________________________________________________________________________________________________
# relu_2 (Activation)             (None, 56, 56, 128)  0           norm_2[0][0]
# __________________________________________________________________________________________________
# relu_b (Activation)             (None, 28, 28, 64)   0           norm_b[0][0]
# __________________________________________________________________________________________________
# conv_2_2 (Conv2D)               (None, 28, 28, 128)  147584      relu_2[0][0]
# __________________________________________________________________________________________________
# conv_b_2 (Conv2D)               (None, 28, 28, 128)  73856       relu_b[0][0]
# __________________________________________________________________________________________________
# norm_2_2 (BatchNormalization)   (None, 28, 28, 128)  512         conv_2_2[0][0]
# __________________________________________________________________________________________________
# norm_b_2 (BatchNormalization)   (None, 28, 28, 128)  512         conv_b_2[0][0]
# __________________________________________________________________________________________________
# conv_c (Conv2D)                 (None, 14, 14, 64)   6976        wavelet[0][3]
# __________________________________________________________________________________________________
# relu_2_2 (Activation)           (None, 28, 28, 128)  0           norm_2_2[0][0]
# __________________________________________________________________________________________________
# relu_b_2 (Activation)           (None, 28, 28, 128)  0           norm_b_2[0][0]
# __________________________________________________________________________________________________
# norm_c (BatchNormalization)     (None, 14, 14, 64)   256         conv_c[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 28, 28, 256)  0           relu_2_2[0][0]
#                                                                  relu_b_2[0][0]
# __________________________________________________________________________________________________
# relu_c (Activation)             (None, 14, 14, 64)   0           norm_c[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv2D)                 (None, 28, 28, 256)  590080      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv_c_2 (Conv2D)               (None, 14, 14, 256)  147712      relu_c[0][0]
# __________________________________________________________________________________________________
# nomr_3 (BatchNormalization)     (None, 28, 28, 256)  1024        conv_3[0][0]
# __________________________________________________________________________________________________
# norm_c_2 (BatchNormalization)   (None, 14, 14, 256)  1024        conv_c_2[0][0]
# __________________________________________________________________________________________________
# relu_3 (Activation)             (None, 28, 28, 256)  0           nomr_3[0][0]
# __________________________________________________________________________________________________
# relu_c_2 (Activation)           (None, 14, 14, 256)  0           norm_c_2[0][0]
# __________________________________________________________________________________________________
# conv_3_2 (Conv2D)               (None, 14, 14, 256)  590080      relu_3[0][0]
# __________________________________________________________________________________________________
# conv_c_3 (Conv2D)               (None, 14, 14, 256)  590080      relu_c_2[0][0]
# __________________________________________________________________________________________________
# norm_3_2 (BatchNormalization)   (None, 14, 14, 256)  1024        conv_3_2[0][0]
# __________________________________________________________________________________________________
# norm_c_3 (BatchNormalization)   (None, 14, 14, 256)  1024        conv_c_3[0][0]
# __________________________________________________________________________________________________
# relu_3_2 (Activation)           (None, 14, 14, 256)  0           norm_3_2[0][0]
# __________________________________________________________________________________________________
# relu_c_3 (Activation)           (None, 14, 14, 256)  0           norm_c_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 14, 14, 512)  0           relu_3_2[0][0]
#                                                                  relu_c_3[0][0]
# __________________________________________________________________________________________________
# conv_4 (Conv2D)                 (None, 14, 14, 256)  1179904     concatenate_3[0][0]
# __________________________________________________________________________________________________
# norm_4 (BatchNormalization)     (None, 14, 14, 256)  1024        conv_4[0][0]
# __________________________________________________________________________________________________
# relu_4 (Activation)             (None, 14, 14, 256)  0           norm_4[0][0]
# __________________________________________________________________________________________________
# conv_4_2 (Conv2D)               (None, 7, 7, 256)    590080      relu_4[0][0]
# __________________________________________________________________________________________________
# norm_4_2 (BatchNormalization)   (None, 7, 7, 256)    1024        conv_4_2[0][0]
# __________________________________________________________________________________________________
# relu_4_2 (Activation)           (None, 7, 7, 256)    0           norm_4_2[0][0]
# __________________________________________________________________________________________________
# conv_5_1 (Conv2D)               (None, 7, 7, 128)    295040      relu_4_2[0][0]
# __________________________________________________________________________________________________
# norm_5_1 (BatchNormalization)   (None, 7, 7, 128)    512         conv_5_1[0][0]
# __________________________________________________________________________________________________
# relu_5_1 (Activation)           (None, 7, 7, 128)    0           norm_5_1[0][0]
# __________________________________________________________________________________________________
# avg_pool_5_1 (AveragePooling2D) (None, 7, 7, 128)    0           relu_5_1[0][0]
# __________________________________________________________________________________________________
# flat_5_1 (Flatten)              (None, 6272)         0           avg_pool_5_1[0][0]
# __________________________________________________________________________________________________
# fc_5 (Dense)                    (None, 2048)         12847104    flat_5_1[0][0]
# __________________________________________________________________________________________________
# norm_5 (BatchNormalization)     (None, 2048)         8192        fc_5[0][0]
# __________________________________________________________________________________________________
# relu_5 (Activation)             (None, 2048)         0           norm_5[0][0]
# __________________________________________________________________________________________________
# drop_5 (Dropout)                (None, 2048)         0           relu_5[0][0]
# __________________________________________________________________________________________________
# fc_6 (Dense)                    (None, 2048)         4196352     drop_5[0][0]
# __________________________________________________________________________________________________
# norm_6 (BatchNormalization)     (None, 2048)         8192        fc_6[0][0]
# __________________________________________________________________________________________________
# relu_6 (Activation)             (None, 2048)         0           norm_6[0][0]
# __________________________________________________________________________________________________
# drop_6 (Dropout)                (None, 2048)         0           relu_6[0][0]
# __________________________________________________________________________________________________
# fc_7 (Dense)                    (None, 1024)         2098176     drop_6[0][0]
# ==================================================================================================
# Total params: 23,584,320
# Trainable params: 23,571,392
# Non-trainable params: 12,928
# __________________________________________________________________________________________________
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# the_input (InputLayer)          (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# wavelet (Lambda)                [(None, 112, 112, 12 0           the_input[0][0]
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 112, 112, 64) 6976        wavelet[0][0]
# __________________________________________________________________________________________________
# norm_1 (BatchNormalization)     (None, 112, 112, 64) 256         conv_1[0][0]
# __________________________________________________________________________________________________
# relu_1 (Activation)             (None, 112, 112, 64) 0           norm_1[0][0]
# __________________________________________________________________________________________________
# conv_1_2 (Conv2D)               (None, 56, 56, 64)   36928       relu_1[0][0]
# __________________________________________________________________________________________________
# conv_a (Conv2D)                 (None, 56, 56, 64)   6976        wavelet[0][1]
# __________________________________________________________________________________________________
# norm_1_2 (BatchNormalization)   (None, 56, 56, 64)   256         conv_1_2[0][0]
# __________________________________________________________________________________________________
# norm_a (BatchNormalization)     (None, 56, 56, 64)   256         conv_a[0][0]
# __________________________________________________________________________________________________
# relu_1_2 (Activation)           (None, 56, 56, 64)   0           norm_1_2[0][0]
# __________________________________________________________________________________________________
# relu_a (Activation)             (None, 56, 56, 64)   0           norm_a[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 56, 56, 128)  0           relu_1_2[0][0]
#                                                                  relu_a[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 56, 56, 128)  147584      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv_b (Conv2D)                 (None, 28, 28, 64)   6976        wavelet[0][2]
# __________________________________________________________________________________________________
# norm_2 (BatchNormalization)     (None, 56, 56, 128)  512         conv_2[0][0]
# __________________________________________________________________________________________________
# norm_b (BatchNormalization)     (None, 28, 28, 64)   256         conv_b[0][0]
# __________________________________________________________________________________________________
# relu_2 (Activation)             (None, 56, 56, 128)  0           norm_2[0][0]
# __________________________________________________________________________________________________
# relu_b (Activation)             (None, 28, 28, 64)   0           norm_b[0][0]
# __________________________________________________________________________________________________
# conv_2_2 (Conv2D)               (None, 28, 28, 128)  147584      relu_2[0][0]
# __________________________________________________________________________________________________
# conv_b_2 (Conv2D)               (None, 28, 28, 128)  73856       relu_b[0][0]
# __________________________________________________________________________________________________
# norm_2_2 (BatchNormalization)   (None, 28, 28, 128)  512         conv_2_2[0][0]
# __________________________________________________________________________________________________
# norm_b_2 (BatchNormalization)   (None, 28, 28, 128)  512         conv_b_2[0][0]
# __________________________________________________________________________________________________
# conv_c (Conv2D)                 (None, 14, 14, 64)   6976        wavelet[0][3]
# __________________________________________________________________________________________________
# relu_2_2 (Activation)           (None, 28, 28, 128)  0           norm_2_2[0][0]
# __________________________________________________________________________________________________
# relu_b_2 (Activation)           (None, 28, 28, 128)  0           norm_b_2[0][0]
# __________________________________________________________________________________________________
# norm_c (BatchNormalization)     (None, 14, 14, 64)   256         conv_c[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 28, 28, 256)  0           relu_2_2[0][0]
#                                                                  relu_b_2[0][0]
# __________________________________________________________________________________________________
# relu_c (Activation)             (None, 14, 14, 64)   0           norm_c[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv2D)                 (None, 28, 28, 256)  590080      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv_c_2 (Conv2D)               (None, 14, 14, 256)  147712      relu_c[0][0]
# __________________________________________________________________________________________________
# nomr_3 (BatchNormalization)     (None, 28, 28, 256)  1024        conv_3[0][0]
# __________________________________________________________________________________________________
# norm_c_2 (BatchNormalization)   (None, 14, 14, 256)  1024        conv_c_2[0][0]
# __________________________________________________________________________________________________
# relu_3 (Activation)             (None, 28, 28, 256)  0           nomr_3[0][0]
# __________________________________________________________________________________________________
# relu_c_2 (Activation)           (None, 14, 14, 256)  0           norm_c_2[0][0]
# __________________________________________________________________________________________________
# conv_3_2 (Conv2D)               (None, 14, 14, 256)  590080      relu_3[0][0]
# __________________________________________________________________________________________________
# conv_c_3 (Conv2D)               (None, 14, 14, 256)  590080      relu_c_2[0][0]
# __________________________________________________________________________________________________
# norm_3_2 (BatchNormalization)   (None, 14, 14, 256)  1024        conv_3_2[0][0]
# __________________________________________________________________________________________________
# norm_c_3 (BatchNormalization)   (None, 14, 14, 256)  1024        conv_c_3[0][0]
# __________________________________________________________________________________________________
# relu_3_2 (Activation)           (None, 14, 14, 256)  0           norm_3_2[0][0]
# __________________________________________________________________________________________________
# relu_c_3 (Activation)           (None, 14, 14, 256)  0           norm_c_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 14, 14, 512)  0           relu_3_2[0][0]
#                                                                  relu_c_3[0][0]
# __________________________________________________________________________________________________
# conv_4 (Conv2D)                 (None, 14, 14, 256)  1179904     concatenate_3[0][0]
# __________________________________________________________________________________________________
# norm_4 (BatchNormalization)     (None, 14, 14, 256)  1024        conv_4[0][0]
# __________________________________________________________________________________________________
# relu_4 (Activation)             (None, 14, 14, 256)  0           norm_4[0][0]
# __________________________________________________________________________________________________
# conv_4_2 (Conv2D)               (None, 7, 7, 256)    590080      relu_4[0][0]
# __________________________________________________________________________________________________
# norm_4_2 (BatchNormalization)   (None, 7, 7, 256)    1024        conv_4_2[0][0]
# __________________________________________________________________________________________________
# relu_4_2 (Activation)           (None, 7, 7, 256)    0           norm_4_2[0][0]
# __________________________________________________________________________________________________
# conv_5_1 (Conv2D)               (None, 7, 7, 128)    295040      relu_4_2[0][0]
# __________________________________________________________________________________________________
# norm_5_1 (BatchNormalization)   (None, 7, 7, 128)    512         conv_5_1[0][0]
# __________________________________________________________________________________________________
# relu_5_1 (Activation)           (None, 7, 7, 128)    0           norm_5_1[0][0]
# __________________________________________________________________________________________________
# avg_pool_5_1 (AveragePooling2D) (None, 7, 7, 128)    0           relu_5_1[0][0]
# __________________________________________________________________________________________________
# flat_5_1 (Flatten)              (None, 6272)         0           avg_pool_5_1[0][0]
# __________________________________________________________________________________________________
# fc_5 (Dense)                    (None, 2048)         12847104    flat_5_1[0][0]
# __________________________________________________________________________________________________
# norm_5 (BatchNormalization)     (None, 2048)         8192        fc_5[0][0]
# __________________________________________________________________________________________________
# relu_5 (Activation)             (None, 2048)         0           norm_5[0][0]
# __________________________________________________________________________________________________
# drop_5 (Dropout)                (None, 2048)         0           relu_5[0][0]
# __________________________________________________________________________________________________
# fc_6 (Dense)                    (None, 2048)         4196352     drop_5[0][0]
# __________________________________________________________________________________________________
# norm_6 (BatchNormalization)     (None, 2048)         8192        fc_6[0][0]
# __________________________________________________________________________________________________
# relu_6 (Activation)             (None, 2048)         0           norm_6[0][0]
# __________________________________________________________________________________________________
# drop_6 (Dropout)                (None, 2048)         0           relu_6[0][0]
# __________________________________________________________________________________________________
# fc_7 (Dense)                    (None, 1024)         2098176     drop_6[0][0]
# ==================================================================================================
# Total params: 23,584,320
# Trainable params: 23,571,392
# Non-trainable params: 12,928
# __________________________________________________________________________________________________

# %%
img1_embed = siamese_model(img1)
img2_embed = siamese_model(img2)

# %%
# Distance calculation for ReID Task
#distance = Lambda(euclidean_distance, output_shape=eucl_dist_output_shape)([img1_embed, img2_embed])

#distance = tf.keras.layers.Lambda( lambda tensors : K.abs( tensors[0] - tensors[1] ))( [img1_embed , img2_embed] )
distance = keras.layers.Lambda( lambda tensors : K.abs( tensors[0] - tensors[1] ))( [img1_embed , img2_embed] )
outputs = Dense(1, activation='sigmoid', name='fc_7')(distance)

# Model that can be trained with anchor, positive negative images
#model = Model(inputs=[img1, img2], outputs=distance)
model = Model(inputs=[img1, img2], outputs=outputs)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# model_1 (Model)                 (None, 1024)         23584320    input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1024)         0           model_1[1][0]
#                                                                  model_1[2][0]
# __________________________________________________________________________________________________
# fc_7 (Dense)                    (None, 1)            1025        lambda_1[0][0]
# ==================================================================================================
# Total params: 23,585,345
# Trainable params: 23,572,417
# Non-trainable params: 12,928
# __________________________________________________________________________________________________

# %%
plot_model(model, show_shapes=True, show_layer_names=True)

# %%
METRICS = [
        tf.keras.metrics.BinaryAccuracy(),
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall"),
        tf.keras.metrics.AUC(name="AUC"),
        tf.keras.metrics.TruePositives(name="true_positives"),
        tf.keras.metrics.TrueNegatives(name="true_negatives"),
        tf.keras.metrics.FalsePositives(name="false_positives"),
        tf.keras.metrics.FalseNegatives(name="false_negatives"),
        keras.metrics.SensitivityAtSpecificity(0.5, name = "sensitivity"),
        keras.metrics.SpecificityAtSensitivity(0.5, name = "specificity")]
    


#model.compile(loss=contrastive_loss, optimizer=keras.optimizers.Adam(lr=0.00001), metrics=[accuracy])
#model.compile(loss=contrastive_loss, optimizer=keras.optimizers.Adam(lr=0.00001), metrics=METRICS)
model.compile(loss=keras.losses.binary_crossentropy, optimizer=keras.optimizers.Adam(lr=0.001), metrics=METRICS)
# Out:
# WARNING:tensorflow:From C:\Users\PC\Anaconda3\envs\grace\lib\site-packages\keras\backend\tensorflow_backend.py:3172: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
history = model.fit([train_X1,train_X2], train_Y,
          batch_size=32, 
          epochs=30,
          verbose=1, validation_split=.20)
          #validation_data=([test_X1,test_X2],test_Y))

model.save('neurowavel_siamese_classification_2class.h5')
# Out:
# WARNING:tensorflow:From C:\Users\PC\Anaconda3\envs\grace\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 3600 samples, validate on 900 samples
# Epoch 1/30
# 3600/3600 [==============================] - 44s 12ms/step - loss: 0.2910 - binary_accuracy: 0.8772 - precision: 0.0690 - recall: 0.0339 - AUC: 0.5853 - true_positives: 2.0000 - true_negatives: 1640.9823 - false_positives: 26.9735 - false_negatives: 153.9026 - sensitivity: 0.7377 - specificity: 0.7493 - val_loss: 0.5908 - val_binary_accuracy: 0.9071 - val_precision: 0.0690 - val_recall: 0.0057 - val_AUC: 0.6365 - val_true_positives: 2.0000 - val_true_negatives: 3698.0688 - val_false_positives: 27.0000 - val_false_negatives: 351.9655 - val_sensitivity: 0.5824 - val_specificity: 0.5735
# Epoch 2/30
# 3600/3600 [==============================] - 36s 10ms/step - loss: 0.2708 - binary_accuracy: 0.9082 - precision: 0.1242 - recall: 0.0072 - AUC: 0.6464 - true_positives: 4.1947 - true_negatives: 5740.1948 - false_positives: 28.4956 - false_negatives: 550.9734 - sensitivity: 0.8295 - specificity: 0.8115 - val_loss: 0.3219 - val_binary_accuracy: 0.9099 - val_precision: 0.1892 - val_recall: 0.0093 - val_AUC: 0.6741 - val_true_positives: 7.0000 - val_true_negatives: 7799.0688 - val_false_positives: 30.0000 - val_false_negatives: 742.9655 - val_sensitivity: 0.7802 - val_specificity: 0.8480
# Epoch 3/30
# 3600/3600 [==============================] - 35s 10ms/step - loss: 0.2451 - binary_accuracy: 0.9104 - precision: 0.3295 - recall: 0.0190 - AUC: 0.6956 - true_positives: 18.4867 - true_negatives: 9835.9297 - false_positives: 35.8850 - false_negatives: 933.5575 - sensitivity: 0.8885 - specificity: 0.8701 - val_loss: 0.3587 - val_binary_accuracy: 0.9112 - val_precision: 0.3832 - val_recall: 0.0229 - val_AUC: 0.7089 - val_true_positives: 26.2414 - val_true_negatives: 11891.0000 - val_false_positives: 42.0690 - val_false_negatives: 1119.7241 - val_sensitivity: 0.7582 - val_specificity: 0.7849
# Epoch 4/30
# 3600/3600 [==============================] - 35s 10ms/step - loss: 0.2196 - binary_accuracy: 0.9118 - precision: 0.4247 - recall: 0.0266 - AUC: 0.7237 - true_positives: 35.8142 - true_negatives: 13937.5400 - false_positives: 47.8407 - false_negatives: 1302.6637 - sensitivity: 0.9443 - specificity: 0.9105 - val_loss: 0.4781 - val_binary_accuracy: 0.9068 - val_precision: 0.3018 - val_recall: 0.0409 - val_AUC: 0.7324 - val_true_positives: 63.1724 - val_true_negatives: 15876.2412 - val_false_positives: 160.8276 - val_false_negatives: 1478.7931 - val_sensitivity: 0.6703 - val_specificity: 0.6131
# Epoch 5/30
# 3600/3600 [==============================] - 35s 10ms/step - loss: 0.2226 - binary_accuracy: 0.9037 - precision: 0.2572 - recall: 0.0545 - AUC: 0.7393 - true_positives: 94.6283 - true_negatives: 17820.7793 - false_positives: 272.2213 - false_negatives: 1636.2301 - sensitivity: 0.9213 - specificity: 0.9096 - val_loss: 0.2960 - val_binary_accuracy: 0.9046 - val_precision: 0.2924 - val_recall: 0.0614 - val_AUC: 0.7488 - val_true_positives: 119.0000 - val_true_negatives: 19853.0684 - val_false_positives: 288.0000 - val_false_negatives: 1818.9656 - val_sensitivity: 0.8462 - val_specificity: 0.8059
# Epoch 6/30
# 3600/3600 [==============================] - 35s 10ms/step - loss: 0.1948 - binary_accuracy: 0.9059 - precision: 0.3367 - recall: 0.0721 - AUC: 0.7608 - true_positives: 154.8319 - true_negatives: 21881.7871 - false_positives: 303.2832 - false_negatives: 1983.9558 - sensitivity: 0.9541 - specificity: 0.9442 - val_loss: 0.4795 - val_binary_accuracy: 0.9041 - val_precision: 0.3288 - val_recall: 0.0871 - val_AUC: 0.7661 - val_true_positives: 203.4828 - val_true_negatives: 23825.1387 - val_false_positives: 419.9310 - val_false_negatives: 2130.4827 - val_sensitivity: 0.6703 - val_specificity: 0.7120
# Epoch 7/30
# 3600/3600 [==============================] - 35s 10ms/step - loss: 0.1753 - binary_accuracy: 0.9024 - precision: 0.3276 - recall: 0.1071 - AUC: 0.7750 - true_positives: 271.1505 - true_negatives: 25741.2383 - false_positives: 554.9646 - false_negatives: 2256.5044 - sensitivity: 0.9738 - specificity: 0.9630 - val_loss: 0.3418 - val_binary_accuracy: 0.9039 - val_precision: 0.3567 - val_recall: 0.1163 - val_AUC: 0.7838 - val_true_positives: 317.4828 - val_true_negatives: 27776.4141 - val_false_positives: 572.6552 - val_false_negatives: 2412.4827 - val_sensitivity: 0.8352 - val_specificity: 0.8331
# Epoch 8/30
# 3600/3600 [==============================] - 36s 10ms/step - loss: 0.1641 - binary_accuracy: 0.9057 - precision: 0.3842 - recall: 0.1253 - AUC: 0.7917 - true_positives: 366.3805 - true_negatives: 29817.5488 - false_positives: 585.7964 - false_negatives: 2554.1328 - sensitivity: 0.9869 - specificity: 0.9730 - val_loss: 0.3235 - val_binary_accuracy: 0.9068 - val_precision: 0.4091 - val_recall: 0.1359 - val_AUC: 0.7991 - val_true_positives: 424.8621 - val_true_negatives: 31839.4141 - val_false_positives: 613.6552 - val_false_negatives: 2701.1035 - val_sensitivity: 0.7802 - val_specificity: 0.8121
# Epoch 9/30
# 3600/3600 [==============================] - 35s 10ms/step - loss: 0.1640 - binary_accuracy: 0.9082 - precision: 0.4334 - recall: 0.1463 - AUC: 0.8057 - true_positives: 486.6637 - true_negatives: 33865.8047 - false_positives: 634.9469 - false_negatives: 2836.4424 - sensitivity: 0.9869 - specificity: 0.9739 - val_loss: 0.3117 - val_binary_accuracy: 0.9094 - val_precision: 0.4552 - val_recall: 0.1559 - val_AUC: 0.8122 - val_true_positives: 549.0690 - val_true_negatives: 35899.8633 - val_false_positives: 657.2069 - val_false_negatives: 2972.8965 - val_sensitivity: 0.9560 - val_specificity: 0.8764
# Epoch 10/30
# 3600/3600 [==============================] - 35s 10ms/step - loss: 0.1497 - binary_accuracy: 0.9104 - precision: 0.4720 - recall: 0.1656 - AUC: 0.8183 - true_positives: 616.1682 - true_negatives: 37916.7188 - false_positives: 688.3452 - false_negatives: 3102.6284 - sensitivity: 0.9836 - specificity: 0.9803 - val_loss: 0.2320 - val_binary_accuracy: 0.9116 - val_precision: 0.4918 - val_recall: 0.1748 - val_AUC: 0.8254 - val_true_positives: 684.8276 - val_true_negatives: 39953.3086 - val_false_positives: 707.7586 - val_false_negatives: 3233.1379 - val_sensitivity: 1.0000 - val_specificity: 0.9456
# Epoch 11/30
# 3600/3600 [==============================] - 35s 10ms/step - loss: 0.1347 - binary_accuracy: 0.9132 - precision: 0.5139 - recall: 0.1852 - AUC: 0.8316 - true_positives: 761.5044 - true_negatives: 41996.6562 - false_positives: 719.3098 - false_negatives: 3346.3894 - sensitivity: 0.9934 - specificity: 0.9921 - val_loss: 0.2254 - val_binary_accuracy: 0.9145 - val_precision: 0.5369 - val_recall: 0.1968 - val_AUC: 0.8381 - val_true_positives: 848.8621 - val_true_negatives: 44033.0000 - val_false_positives: 732.0690 - val_false_negatives: 3465.1035 - val_sensitivity: 0.9451 - val_specificity: 0.9271
# Epoch 12/30
# 3600/3600 [==============================] - 35s 10ms/step - loss: 0.1354 - binary_accuracy: 0.9158 - precision: 0.5539 - recall: 0.2077 - AUC: 0.8448 - true_positives: 935.9380 - true_negatives: 46067.5859 - false_positives: 753.0797 - false_negatives: 3567.2566 - sensitivity: 0.9934 - specificity: 0.9863 - val_loss: 0.3660 - val_binary_accuracy: 0.9163 - val_precision: 0.5630 - val_recall: 0.2160 - val_AUC: 0.8470 - val_true_positives: 1017.4828 - val_true_negatives: 48079.2070 - val_false_positives: 789.8621 - val_false_negatives: 3692.4827 - val_sensitivity: 0.6593 - val_specificity: 0.7095
# Epoch 13/30
# 3600/3600 [==============================] - 35s 10ms/step - loss: 0.1272 - binary_accuracy: 0.9173 - precision: 0.5771 - recall: 0.2282 - AUC: 0.8509 - true_positives: 1122.4602 - true_negatives: 50086.6367 - false_positives: 821.5221 - false_negatives: 3793.2390 - sensitivity: 0.9869 - specificity: 0.9924 - val_loss: 0.3489 - val_binary_accuracy: 0.9183 - val_precision: 0.5886 - val_recall: 0.2363 - val_AUC: 0.8535 - val_true_positives: 1206.4828 - val_true_negatives: 52129.9648 - val_false_positives: 843.1035 - val_false_negatives: 3899.4827 - val_sensitivity: 0.7802 - val_specificity: 0.8344
# Epoch 14/30
# 3600/3600 [==============================] - 35s 10ms/step - loss: 0.1098 - binary_accuracy: 0.9193 - precision: 0.6025 - recall: 0.2454 - AUC: 0.8566 - true_positives: 1304.0354 - true_negatives: 54153.8125 - false_positives: 859.5132 - false_negatives: 4006.4956 - sensitivity: 0.9934 - specificity: 0.9948 - val_loss: 0.2365 - val_binary_accuracy: 0.9205 - val_precision: 0.6134 - val_recall: 0.2577 - val_AUC: 0.8610 - val_true_positives: 1418.1379 - val_true_negatives: 56183.2070 - val_false_positives: 893.8621 - val_false_negatives: 4083.8276 - val_sensitivity: 0.9560 - val_specificity: 0.9345
# Epoch 15/30
# 3600/3600 [==============================] - 35s 10ms/step - loss: 0.0969 - binary_accuracy: 0.9214 - precision: 0.6233 - recall: 0.2691 - AUC: 0.8658 - true_positives: 1535.0885 - true_negatives: 58194.0273 - false_positives: 926.8849 - false_negatives: 4167.8584 - sensitivity: 0.9967 - specificity: 0.9954 - val_loss: 0.2798 - val_binary_accuracy: 0.9224 - val_precision: 0.6334 - val_recall: 0.2790 - val_AUC: 0.8688 - val_true_positives: 1645.5862 - val_true_negatives: 60228.8281 - val_false_positives: 952.2414 - val_false_negatives: 4252.3794 - val_sensitivity: 0.9121 - val_specificity: 0.9098
# Epoch 16/30
# 3600/3600 [==============================] - 35s 10ms/step - loss: 0.0954 - binary_accuracy: 0.9234 - precision: 0.6438 - recall: 0.2886 - AUC: 0.8731 - true_positives: 1759.5310 - true_negatives: 62256.4609 - false_positives: 972.7610 - false_negatives: 4335.1060 - sensitivity: 0.9967 - specificity: 0.9982 - val_loss: 0.2484 - val_binary_accuracy: 0.9243 - val_precision: 0.6518 - val_recall: 0.2979 - val_AUC: 0.8767 - val_true_positives: 1874.6552 - val_true_negatives: 64283.5508 - val_false_positives: 1001.5172 - val_false_negatives: 4419.3105 - val_sensitivity: 0.9780 - val_specificity: 0.9184
# Epoch 17/30
# 3600/3600 [==============================] - 35s 10ms/step - loss: 0.0815 - binary_accuracy: 0.9252 - precision: 0.6612 - recall: 0.3060 - AUC: 0.8802 - true_positives: 1985.9646 - true_negatives: 66318.5156 - false_positives: 1016.8761 - false_negatives: 4502.5044 - sensitivity: 0.9967 - specificity: 0.9973 - val_loss: 0.4039 - val_binary_accuracy: 0.9257 - val_precision: 0.6633 - val_recall: 0.3149 - val_AUC: 0.8827 - val_true_positives: 2106.5862 - val_true_negatives: 68319.6562 - val_false_positives: 1069.4138 - val_false_negatives: 4583.3794 - val_sensitivity: 0.7802 - val_specificity: 0.7417
# Epoch 18/30
# 3600/3600 [==============================] - 35s 10ms/step - loss: 0.0888 - binary_accuracy: 0.9260 - precision: 0.6621 - recall: 0.3236 - AUC: 0.8850 - true_positives: 2230.1504 - true_negatives: 70295.3750 - false_positives: 1137.5575 - false_negatives: 4660.7788 - sensitivity: 0.9902 - specificity: 0.9982 - val_loss: 0.2330 - val_binary_accuracy: 0.9268 - val_precision: 0.6690 - val_recall: 0.3308 - val_AUC: 0.8879 - val_true_positives: 2343.8276 - val_true_negatives: 72333.4141 - val_false_positives: 1159.6552 - val_false_negatives: 4742.1377 - val_sensitivity: 0.9780 - val_specificity: 0.9246
# Epoch 19/30
# 3600/3600 [==============================] - 35s 10ms/step - loss: 0.0822 - binary_accuracy: 0.9275 - precision: 0.6757 - recall: 0.3383 - AUC: 0.8906 - true_positives: 2465.1416 - true_negatives: 74355.8672 - false_positives: 1182.8053 - false_negatives: 4820.0444 - sensitivity: 0.9967 - specificity: 0.9979 - val_loss: 0.2675 - val_binary_accuracy: 0.9284 - val_precision: 0.6830 - val_recall: 0.3460 - val_AUC: 0.8929 - val_true_positives: 2588.8621 - val_true_negatives: 76395.5156 - val_false_positives: 1201.5518 - val_false_negatives: 4893.1035 - val_sensitivity: 0.8571 - val_specificity: 0.9740
# Epoch 20/30
# 3600/3600 [==============================] - 35s 10ms/step - loss: 0.0983 - binary_accuracy: 0.9290 - precision: 0.6877 - recall: 0.3524 - AUC: 0.8950 - true_positives: 2705.2212 - true_negatives: 78418.9922 - false_positives: 1228.4336 - false_negatives: 4971.2124 - sensitivity: 0.9934 - specificity: 0.9961 - val_loss: 0.2588 - val_binary_accuracy: 0.9294 - val_precision: 0.6911 - val_recall: 0.3572 - val_AUC: 0.8969 - val_true_positives: 2814.2068 - val_true_negatives: 80443.4141 - val_false_positives: 1257.6552 - val_false_negatives: 5063.7588 - val_sensitivity: 0.9780 - val_specificity: 0.9271
# Epoch 21/30
# 3600/3600 [==============================] - 35s 10ms/step - loss: 0.0556 - binary_accuracy: 0.9303 - precision: 0.6988 - recall: 0.3659 - AUC: 0.8997 - true_positives: 2957.6548 - true_negatives: 82468.0703 - false_positives: 1274.2566 - false_negatives: 5123.8760 - sensitivity: 0.9967 - specificity: 0.9997 - val_loss: 0.2126 - val_binary_accuracy: 0.9313 - val_precision: 0.7062 - val_recall: 0.3739 - val_AUC: 0.9021 - val_true_positives: 3093.2759 - val_true_negatives: 84518.0000 - val_false_positives: 1287.0690 - val_false_negatives: 5180.6895 - val_sensitivity: 0.8681 - val_specificity: 0.9901
# Epoch 22/30
# 3600/3600 [==============================] - 35s 10ms/step - loss: 0.0664 - binary_accuracy: 0.9322 - precision: 0.7134 - recall: 0.3824 - AUC: 0.9047 - true_positives: 3238.0620 - true_negatives: 86557.8750 - false_positives: 1300.2124 - false_negatives: 5227.7080 - sensitivity: 0.9967 - specificity: 0.9994 - val_loss: 0.1239 - val_binary_accuracy: 0.9330 - val_precision: 0.7187 - val_recall: 0.3908 - val_AUC: 0.9073 - val_true_positives: 3388.4482 - val_true_negatives: 88582.5547 - val_false_positives: 1326.5172 - val_false_negatives: 5281.5171 - val_sensitivity: 1.0000 - val_specificity: 0.9827
# Epoch 23/30
# 3600/3600 [==============================] - 36s 10ms/step - loss: 0.0482 - binary_accuracy: 0.9339 - precision: 0.7252 - recall: 0.4000 - AUC: 0.9102 - true_positives: 3545.7168 - true_negatives: 90617.2266 - false_positives: 1343.3451 - false_negatives: 5317.5664 - sensitivity: 0.9967 - specificity: 1.0000 - val_loss: 0.1405 - val_binary_accuracy: 0.9347 - val_precision: 0.7310 - val_recall: 0.4076 - val_AUC: 0.9127 - val_true_positives: 3695.6553 - val_true_negatives: 92653.1719 - val_false_positives: 1359.8966 - val_false_negatives: 5370.3105 - val_sensitivity: 1.0000 - val_specificity: 0.9889
# Epoch 24/30
# 3600/3600 [==============================] - 36s 10ms/step - loss: 0.0467 - binary_accuracy: 0.9356 - precision: 0.7370 - recall: 0.4169 - AUC: 0.9155 - true_positives: 3862.6638 - true_negatives: 94682.3750 - false_positives: 1378.2124 - false_negatives: 5400.6108 - sensitivity: 1.0000 - specificity: 0.9997 - val_loss: 0.6721 - val_binary_accuracy: 0.9350 - val_precision: 0.7230 - val_recall: 0.4236 - val_AUC: 0.9157 - val_true_positives: 4008.4138 - val_true_negatives: 96580.3828 - val_false_positives: 1536.6897 - val_false_negatives: 5453.5518 - val_sensitivity: 0.6264 - val_specificity: 0.5661
# Epoch 25/30
# 3600/3600 [==============================] - 36s 10ms/step - loss: 0.0519 - binary_accuracy: 0.9349 - precision: 0.7163 - recall: 0.4293 - AUC: 0.9163 - true_positives: 4144.3540 - true_negatives: 98529.6250 - false_positives: 1641.3540 - false_negatives: 5508.5220 - sensitivity: 0.9934 - specificity: 0.9991 - val_loss: 0.1338 - val_binary_accuracy: 0.9356 - val_precision: 0.7210 - val_recall: 0.4369 - val_AUC: 0.9187 - val_true_positives: 4306.7588 - val_true_negatives: 100554.1406 - val_false_positives: 1666.9310 - val_false_negatives: 5551.2070 - val_sensitivity: 1.0000 - val_specificity: 0.9889
# Epoch 26/30
# 3600/3600 [==============================] - 36s 10ms/step - loss: 0.0448 - binary_accuracy: 0.9364 - precision: 0.7270 - recall: 0.4446 - AUC: 0.9209 - true_positives: 4472.6372 - true_negatives: 102584.6406 - false_positives: 1679.6372 - false_negatives: 5586.9468 - sensitivity: 1.0000 - specificity: 0.9991 - val_loss: 0.2231 - val_binary_accuracy: 0.9371 - val_precision: 0.7316 - val_recall: 0.4497 - val_AUC: 0.9223 - val_true_positives: 4611.4482 - val_true_negatives: 104632.9297 - val_false_positives: 1692.1379 - val_false_negatives: 5642.5171 - val_sensitivity: 0.9341 - val_specificity: 0.9691
# Epoch 27/30
# 3600/3600 [==============================] - 36s 10ms/step - loss: 0.0432 - binary_accuracy: 0.9377 - precision: 0.7362 - recall: 0.4552 - AUC: 0.9239 - true_positives: 4756.2744 - true_negatives: 106671.1719 - false_positives: 1704.1327 - false_negatives: 5692.2832 - sensitivity: 0.9967 - specificity: 1.0000 - val_loss: 0.1546 - val_binary_accuracy: 0.9385 - val_precision: 0.7415 - val_recall: 0.4610 - val_AUC: 0.9256 - val_true_positives: 4909.5518 - val_true_negatives: 108717.4844 - val_false_positives: 1711.5862 - val_false_negatives: 5740.4136 - val_sensitivity: 0.9890 - val_specificity: 0.9975
# Epoch 28/30
# 3600/3600 [==============================] - 36s 10ms/step - loss: 0.0402 - binary_accuracy: 0.9393 - precision: 0.7474 - recall: 0.4679 - AUC: 0.9275 - true_positives: 5076.8672 - true_negatives: 110758.5234 - false_positives: 1715.6637 - false_negatives: 5772.8052 - sensitivity: 0.9934 - specificity: 0.9997 - val_loss: 0.2225 - val_binary_accuracy: 0.9398 - val_precision: 0.7509 - val_recall: 0.4724 - val_AUC: 0.9286 - val_true_positives: 5218.5171 - val_true_negatives: 112801.5156 - val_false_positives: 1731.5518 - val_false_negatives: 5827.4482 - val_sensitivity: 0.8462 - val_specificity: 0.9666
# Epoch 29/30
# 3600/3600 [==============================] - 36s 10ms/step - loss: 0.0371 - binary_accuracy: 0.9404 - precision: 0.7542 - recall: 0.4782 - AUC: 0.9300 - true_positives: 5372.1860 - true_negatives: 114839.4766 - false_positives: 1750.1416 - false_negatives: 5862.0532 - sensitivity: 0.9967 - specificity: 0.9997 - val_loss: 0.0965 - val_binary_accuracy: 0.9411 - val_precision: 0.7586 - val_recall: 0.4843 - val_AUC: 0.9317 - val_true_positives: 5541.2412 - val_true_negatives: 116873.8281 - val_false_positives: 1763.2413 - val_false_negatives: 5900.7241 - val_sensitivity: 1.0000 - val_specificity: 0.9938
# Epoch 30/30
# 3600/3600 [==============================] - 36s 10ms/step - loss: 0.0510 - binary_accuracy: 0.9418 - precision: 0.7629 - recall: 0.4912 - AUC: 0.9333 - true_positives: 5721.0708 - true_negatives: 118898.6953 - false_positives: 1777.8230 - false_negatives: 5926.2656 - sensitivity: 0.9803 - specificity: 0.9991 - val_loss: 0.2111 - val_binary_accuracy: 0.9422 - val_precision: 0.7650 - val_recall: 0.4943 - val_AUC: 0.9340 - val_true_positives: 5851.6895 - val_true_negatives: 120943.6875 - val_false_positives: 1797.3793 - val_false_negatives: 5986.2759 - val_sensitivity: 0.9231 - val_specificity: 0.9580

# %%
fig, ax = plt.subplots(4, 3, figsize=(20, 20))
ax = ax.ravel()

for i, met in enumerate(["precision", "recall", "binary_accuracy", "loss", "AUC", "true_positives", "true_negatives",
                        "false_positives", "false_negatives", "sensitivity", "specificity"]):
    ax[i].plot(history.history[met], 'b--')
    ax[i].plot(history.history["val_" + met], 'r-v')
    ax[i].set_title("Model {}".format(met))
    ax[i].set_xlabel("epochs")
    ax[i].set_ylabel(met)
    ax[i].legend(["train", "val"])

# %%
acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

#Plot Train and Validation Loss
plt.plot(epochs, loss, 'b--', label='Training  Loss')
plt.plot(epochs, val_loss, 'r-v', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()


#Plot Train and Validation Accuracy
plt.plot(epochs, acc, 'b--', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r-v', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.legend()
plt.show()

# %%
metrics = model.evaluate( [test_X1,test_X2],test_Y ) 
print( 'Loss of {} and Accuracy is {} %'.format( metrics[0] , metrics[1] * 100 ) )
# Out:
# 5701/5701 [==============================] - 20s 3ms/step
# Loss of 0.18762305498102258 and Accuracy is 94.18569207191467 %

# %%
metrics = model.evaluate( [train_X1,train_X2], train_Y ) 
print( 'Loss of {} and Accuracy is {} %'.format( metrics[0] , metrics[1] * 100 ) )
# Out:
# 4500/4500 [==============================] - 16s 3ms/step
# Loss of 0.16075423559215335 and Accuracy is 94.18060183525085 %

# %%
acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy']
pre = history.history['precision']
val_pre = history.history['val_precision']
rcall = history.history['recall']
val_rcall = history.history['val_recall']
aruc = history.history['AUC']
val_aruc = history.history['val_AUC']
loss = history.history['loss']
val_loss = history.history['val_loss']
true_pos = history.history['true_positives']
true_neg = history.history['true_negatives']
false_pos = history.history['false_positives']
false_neg = history.history['false_negatives']
val_true_pos = history.history['val_true_positives']
val_true_neg = history.history['val_true_negatives']
val_false_pos = history.history['val_false_positives']
val_false_neg = history.history['val_false_negatives']
epochs = range(1, len(acc) + 1)

# %%
#Train and validation accuracy
plt.plot(epochs, acc, 'b--', label='Training accurarcy')
plt.plot(epochs, val_acc, 'r-v', label='Validation accurarcy')
plt.title('Training and Validation accurarcy')
plt.legend()

plt.figure()
#Train and validation loss
plt.plot(epochs, loss, 'b--', label='Training loss')
plt.plot(epochs, val_loss, 'r-v', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %%
#Train and validation accuracy on Model Precision
plt.plot(epochs, pre, 'b--', label='Training precision')
plt.plot(epochs, val_pre, 'r-v', label='Validation precision')
plt.title('Model Precision')
plt.legend()

# %%
#Train and validation accuracy on Model Recall
plt.plot(epochs, rcall, 'b--', label='Training recall')
plt.plot(epochs, val_rcall, 'r-v', label='Validation recall')
plt.title('Model Recall')
plt.legend()

# %%
#Train and validation accuracy on Model AUC
plt.plot(epochs, aruc, 'b--', label='Training AUC')
plt.plot(epochs, val_aruc, 'r-v', label='Validation AUC')
plt.title('AUC')
plt.legend()

# %%
#Train and validation accuracy on True positives
plt.plot(epochs, true_pos, 'b--', label='Training True Positives')
plt.plot(epochs, val_true_pos, 'r-v', label='Validation True Positives')
plt.title('Training and Validation True Positives')
plt.legend()
plt.show()

# %%
##Train and validation accuracy on True Negatives 
plt.plot(epochs, true_neg, 'b--', label='Training True Negatives')
plt.plot(epochs, val_true_neg, 'r-v', label='Validation True Negatives')
plt.title('Training and Validation True Negatives')
plt.legend()
plt.show()

# %%
##Train and validation accuracy on False Positives
plt.plot(epochs, false_pos, 'b--', label='Training False Positives')
plt.plot(epochs, val_false_pos, 'r-v', label='Validation False Positives')
plt.title('Training and Validation False Positives')
plt.legend()
plt.show()

# %%
##Train and validation accuracy on False Negatives
plt.plot(epochs, false_neg, 'b--', label='Training False Negatives')
plt.plot(epochs, val_false_neg, 'r-v', label='Validation False Negatives')
plt.title('Training and Validation False Negatives')
plt.legend()
plt.show()

# %%
y_pred = model.predict([test_X1,test_X2])
y_pred = (y_pred >= 0.5)

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sn
warnings.filterwarnings("ignore")
fig = plt.figure(num = None, figsize=(10, 10), dpi=40, facecolor ='w', edgecolor='k')
cm = confusion_matrix(test_Y , y_pred)
conf_matrix = pd.DataFrame(data = cm, 
                           columns = ['Similar', 'Not Similar'], 
                           index = ['Similar', 'Not Similar'])
sn.set(font_scale = 1.8)# for label size
sn.heatmap(conf_matrix, annot = True,fmt='.0f', annot_kws = {"size":25}, cmap="Oranges")#font size
plt.title('Confusion Matrix', fontsize =30)
plt.show()

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sn
warnings.filterwarnings("ignore")
fig = plt.figure(num = None, figsize=(10, 10), dpi=40, facecolor ='w', edgecolor='k')
cm = confusion_matrix(test_Y, y_pred)
conf_matrix = pd.DataFrame(data = cm, 
                            columns = ['Similar', 'Not Similar'], 
                           index = ['Similar', 'Not Similar'])
sn.set(font_scale = 1.8)# for label size
sn.heatmap(conf_matrix/np.sum(conf_matrix), annot = True,fmt='.2%', annot_kws = {"size":25}, cmap="Blues")#font size
plt.title('Confusion Matrix', fontsize =30)
plt.show()
#conf_matrix

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sn
warnings.filterwarnings("ignore")
fig = plt.figure(num = None, figsize=(10, 10), dpi=40, facecolor ='w', edgecolor='k')
cm = confusion_matrix(test_Y, y_pred)

conf_matrix = pd.DataFrame(data = cm, 
                            columns = ['Similar', 'Not Similar'], 
                           index = ['Similar', 'Not Similar'])

labels = ['True Neg','False Pos','False Neg','True Pos']
labels = np.asarray(labels).reshape(2,2)

sn.set(font_scale = 1.8)# for label size
sn.heatmap(conf_matrix, annot =labels, fmt='', annot_kws = {"size":25}, cmap="Oranges")#font size
plt.title('Confusion Matrix', fontsize =30)
plt.show()

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sn

from cf_matrix import make_confusion_matrix
sn.set_context('talk')

warnings.filterwarnings("ignore")
fig = plt.figure(num = None, figsize=(10, 10), dpi=40, facecolor ='w', edgecolor='k')
cm = confusion_matrix(test_Y, y_pred)

conf_matrix = np.array(conf_matrix)

#conf_matrix = np.array([[266,  4],
                     # [ 10, 261]])

labels = ['True Neg','False Pos','False Neg','True Pos']
categories = ['Similar', 'Not Similar']

make_confusion_matrix(conf_matrix, group_names=labels, categories=categories, cmap='Blues', title='Confusion Matrix')

#sn.set(font_scale = 1.8)# for label size
#sn.heatmap(conf_matrix, annot =labels, fmt='', annot_kws = {"size":25}, cmap="Oranges")#font size
#plt.title('Confusion Matrix', fontsize =30)
#plt.show()
#conf_matrix

# %%
from sklearn import metrics
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import auc
from sklearn.metrics import roc_auc_score
from sklearn.metrics import average_precision_score

#r = np.flip(sklearn.metrics.confusion_matrix(y_true, y_pred))
r = (confusion_matrix(test_Y, y_pred))
print("Confusion Matrix")
print(r)

#precision = sklearn.metrics.precision_score(y_true=y_true, y_pred=y_pred, pos_label="positive")
precision = precision_score(y_true=test_Y, y_pred=y_pred)
print('precision')
print(precision)

#recall = sklearn.metrics.recall_score(y_true=test_Y, y_pred=y_pred, pos_label="positive")
recall = recall_score(y_true=test_Y, y_pred=y_pred)
print('recall')                      
print(recall)


#recall = sklearn.metrics.recall_score(y_true=test_Y, y_pred=y_pred, pos_label="positive")
roc_auc = roc_auc_score(test_Y, y_pred, average=None)
print('ROC AUC')                      
print(roc_auc)

#average_precision = average_precision_score(test_Y, y_pred)
#print('Average Precision')                      
#print(average_precision)
# Out:
# Confusion Matrix
# [[5092  102]
#  [ 286  221]]
# precision
# 0.6842105263157895
# recall
# 0.4358974358974359
# ROC AUC
# 0.708129696000316

# %%
#cm = confusion_matrix(testY.argmax(axis=1), predIdxs)
cm = confusion_matrix(test_Y, y_pred)
total = sum(sum(cm))
acc = (cm[0, 0] + cm[1, 1]) / total
sensitivity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
specificity = cm[1, 1] / (cm[0, 1] + cm[1, 1])

# show the confusion matrix, accuracy, sensitivity, and specificity
print('Confusion Matrix')
print(cm)
print("accuracy: {:.4f}".format(acc))
print("sensitivity: {:.4f}".format(sensitivity))
print("specificity: {:.4f}".format(specificity))
# Out:
# Confusion Matrix
# [[5092  102]
#  [ 286  221]]
# accuracy: 0.9319
# sensitivity: 0.9804
# specificity: 0.6842

# %%
from sklearn.metrics import classification_report
target_names = ['Similar', 'Not Similar']

print(classification_report(test_Y, y_pred, target_names = target_names ))
# Out:
#               precision    recall  f1-score   support
#
#      Similar       0.95      0.98      0.96      5194
#  Not Similar       0.68      0.44      0.53       507
#
#     accuracy                           0.93      5701
#    macro avg       0.82      0.71      0.75      5701
# weighted avg       0.92      0.93      0.92      5701

# %%
from keras import backend as K
import gc

K.clear_session()
gc.collect()

del model

# %%
# you will need to install numba using "pip install numba"
from numba import cuda

cuda.select_device(0)
cuda.close()
